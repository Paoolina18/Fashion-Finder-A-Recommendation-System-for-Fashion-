# %%
# import pandas as pd
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from datetime import datetime
import time
import pandas as pd
import re
import numpy as np
import json
import glob


multiple_users= True
# 🔧 Evaluación de prendas de la marca By Paola Ospina
evaluar_marca = True # 🔁 Cambia a False para desactivar esta lógica
marca_objetivo = "By Paola Ospina"

def inicializar_sistema(multiple_users=False):
    """
    Inicializa el sistema de FashionIA:
    - Pide el nombre del usuario si multiple_users está activo
    - Crea carpetas y archivos necesarios
    - Carga imágenes, categorías, feedback y Q-table
    """


    global username, user_folder, category_file, feedback_dir, q_table_path
    global df, feedback_db, q_table
    global ruta_kpis, ruta_dashboard, ruta_imagen, ruta_feedback_csv
    global param_file


    # 1. Definir usuario
    username = input("🔐 Ingrese el nombre del usuario: ").strip().lower() if multiple_users else "pao"

    # 2. Rutas del usuario
    base_path = r"C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet"
    user_path = os.path.join(base_path, username)
    user_folder = os.path.join(user_path, "Fotos")
    category_file = os.path.join(user_path, f"categorias_{username}.xlsx")
    feedback_dir = os.path.join(user_path, "Feedback")
    q_table_path = os.path.join(user_path, "q_table.xlsx")
    param_file = os.path.join(user_path, "params.json")  # 📌 Archivo de parámetros por usuario
    ruta_kpis = os.path.join(user_path, "kpis.xlsx")
    ruta_dashboard = os.path.join(user_path, "dashboard.xlsx")
    ruta_imagen = os.path.join(user_path, "curva_aprendizaje.png")
    ruta_feedback_csv = os.path.join(feedback_dir, "feedback.csv")
    q_table_path = os.path.join(user_path, "q_table.xlsx")
    
        
    # 3. Crear carpetas si no existen
    os.makedirs(user_folder, exist_ok=True)
    os.makedirs(feedback_dir, exist_ok=True)



    # 3.5 Cargar o inicializar parámetros de aprendizaje
    default_params = {"alpha": 0.1, "gamma": 0.9, "epsilon": 1.0, "decay_rate": 0.995}
    if os.path.exists(param_file):
        with open(param_file, 'r') as f:
            params = json.load(f)
        print("🔁 Parámetros de aprendizaje cargados desde archivo.")
    else:
        params = default_params
        with open(param_file, 'w') as f:
            json.dump(params, f)
        print("🆕 Archivo de parámetros creado con valores por defecto.")
    
    # Asignar a variables globales
    global alpha, gamma, epsilon, decay_rate
    alpha = params["alpha"]
    gamma = params["gamma"]
    epsilon = params["epsilon"]
    decay_rate = params["decay_rate"]


    # 4. Crear archivo de categorías si no existe
    CATEGORY_COLUMNS = ["Image_ID", "Type", "Color", "Weather", "Style", "Occasion"]
    if not os.path.exists(category_file):
        pd.DataFrame(columns=CATEGORY_COLUMNS).to_excel(category_file, index=False)
        print(f"📂 Archivo de categorías creado: {category_file}")
    else:
        print(f"✅ Archivo de categorías encontrado: {category_file}")


    # 5. Cargar imágenes y categorías
    def create_dataframe(folder):
        data = []
        for file in os.listdir(folder):
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                try:
                    image_id = int(os.path.splitext(file)[0])
                    file_path = os.path.join(folder, file)
                    data.append({'Image_ID': image_id, 'Image': file_path})
                except ValueError:
                    print(f"⚠️ Archivo inválido: {file}")
        return pd.DataFrame(data).sort_values("Image_ID").reset_index(drop=True)

    def load_categories(file):
        try:
            return pd.read_excel(file)
        except:
            print("❌ No se pudo cargar el archivo de categorías.")
            return pd.DataFrame()

    df_images = create_dataframe(user_folder)
    df_categories = load_categories(category_file)
    
    if "Image" in df_categories.columns:
        df_categories = df_categories.drop(columns=["Image"])
        # Asegurarse de que 'Image' se construya correctamente desde 'Image_ID'
    df_categories["Image"] = df_categories["Image_ID"].apply(
        lambda x: os.path.join(user_folder, f"{x}.jpg")
    ) 

    if df_images.empty or df_categories.empty:
        print("❌ Error: faltan imágenes o categorías.")
        df = pd.DataFrame()
    else:
        # Construir la ruta de la imagen directamente desde el Image_ID
        df = df_categories.copy()
        df["Image"] = df["Image_ID"].apply(lambda x: os.path.join(user_folder, f"{x}.jpg"))
        
        # Rellenar campos faltantes y asegurar columna Weight
        df.fillna({
            "Type": "Unknown",
            "Color": "Unknown",
            "Weather": "All",
            "Style": "Casual",
            "Occasion": "Any"
        }, inplace=True)
        
        if 'Weight' not in df.columns:
            df['Weight'] = 0.0

        print(f"✅ {len(df)} prendas cargadas para el usuario '{username}'")

    # 6. Cargar feedback histórico
    feedback_db = []
    feedback_files = glob.glob(os.path.join(feedback_dir, "feedback_*.csv"))
    if feedback_files:
        dfs = [pd.read_csv(f) for f in feedback_files]
        feedback_hist = pd.concat(dfs, ignore_index=True)
        feedback_hist.drop_duplicates(subset=["Outfit_ID", "Image_ID", "Timestamp"], inplace=True)
        feedback_db = feedback_hist.to_dict('records')
        print(f"📈 Feedback cargado: {len(feedback_db)} entradas.")
    else:
        print("📭 No se encontró feedback previo.")

    # 7. Cargar Q-table del usuario
    q_table = {}
    if os.path.exists(q_table_path):
        df_qtable = pd.read_excel(q_table_path)
        if "State" in df_qtable.columns and "Action" in df_qtable.columns:
            q_table = {(eval(row["State"]), eval(row["Action"])): row["Q-Value"] for _, row in df_qtable.iterrows()}
            print(f"🔄 Q-Table cargada con {len(q_table)} combinaciones.")
        else:
            print("⚠️ Q-Table con formato incompatible.")
    else:
        print("🆕 No se encontró Q-Table previa. Se iniciará vacía.")

    print(f"🚀 Inicialización completa para: {username}")

inicializar_sistema(multiple_users)  # o False si solo usarás 'pao'
  # 🚨 Cambia a True para permitir input dinámico

def guardar_feedback(outfit, rewards, fuente="Humano"):
    """
    Guarda el feedback de un outfit en un archivo CSV.
    `outfit`: lista de diccionarios con las prendas (cada uno debe tener keys como 'Image_ID', 'Type', 'Brand', 'Color').
    `rewards`: lista de enteros (+1 o -1) con el reward para cada prenda.
    `fuente`: "Humano" o "IA"
    """

    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    feedback_file = ruta_feedback_csv

    # Si el archivo ya existe, obtenemos el último Outfit_ID
    if os.path.exists(feedback_file):
        existing_df = pd.read_csv(feedback_file)
        last_outfit_id = existing_df["Outfit_ID"].max() + 1
    else:
        last_outfit_id = 1

    # Crear nuevo DataFrame de feedback
    data = []
    for i, prenda in enumerate(outfit):
        fila = {
            "Outfit_ID": last_outfit_id,
            "Image_ID": prenda.get("Image_ID"),
            "Type": prenda.get("Type"),
            "Brand": prenda.get("Brand"),
            "Color": prenda.get("Color"),
            "Reward": rewards[i],
            "Fuente": fuente,
            "Timestamp": timestamp
        }
        data.append(fila)

    df_nuevo = pd.DataFrame(data)

    # Guardar en modo append para no sobrescribir
    df_nuevo.to_csv(feedback_file, mode="a", index=False, header=not os.path.exists(feedback_file))


## GUARDAR HIPERPARAMETROS

def save_params():
    """
    Guarda los parámetros de aprendizaje (incluyendo epsilon actualizado) en params.json.
    """
    params = {
        "alpha": alpha,
        "gamma": gamma,
        "epsilon": epsilon,
        "decay_rate": decay_rate
    }
    with open(param_file, 'w') as f:
        json.dump(params, f)
    print(f"🛠️ Parámetros de aprendizaje guardados: ε={epsilon:.4f}")

#########################
def get_user_paths(username):
    """
    Devuelve rutas personalizadas basadas en el nombre del usuario.
    """
    base_path = r"C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet"
    user_folder = os.path.join(base_path, username, "Fotos")
    category_file = os.path.join(base_path, username, f"categorias_{username}.xlsx")
    return user_folder, category_file
## DEFINIR DICCIONARIOS

# Diccionarios de codificación globales
type_encoding = {"Top": 0, "Bottom": 1, "Dress": 2, "Jacket": 3, "Hoodie": 4}
color_encoding = {"White": 0, "Black": 1, "Red": 2, "Blue": 3, "Yellow": 4, "Purple": 5, 
                  "Orange": 6, "Green": 7, "Gray": 8, "Rose": 9, "Beige": 10, "Brown": 11}
style_encoding = {"Casual": 0, "Formal": 1, "Elegante": 2, "Urbano": 3}
occasion_encoding = {"Fiesta": 0, "Diario": 1, "Cena": 2, "Trabajo": 3}
weather_encoding = {"Frío": 0, "Cálido": 1, "Todas": 2}
material_encoding = {"Lana": 1, "Poliéster": 2, "Seda": 3, "Algodón": 4, "Cuero": 5, "Jean": 6, "Licra": 7, "Lino": 8}
fit_encoding = {"Regular": 1, "Ajustado": 2, "Oversized": 3}
length_encoding = {"Corto": 1, "Largo": 2, "Medio": 3}
brand_encoding = {"Nike": 1, "Adidas": 2, "Gucci": 3, "Todas": 4}



###_____________________________________________________________________
def load_categories_from_excel(category_file):
    """
    Carga el archivo de categorías desde Excel y lo devuelve como un DataFrame.
    """
    if not os.path.exists(category_file):
        print(f"🚨 Error: No se encontró el archivo {category_file}")
        return pd.DataFrame()

    try:
        df_categories = pd.read_excel(category_file)
        print(f"✅ Categorías cargadas exitosamente desde {category_file}")
        return df_categories
    except Exception as e:
        print(f"🚨 Error al cargar el archivo de categorías: {e}")
        return pd.DataFrame()

# 🔹 Mueve la definición de create_dataframe() antes de que se use en create_full_dataframe()
def create_dataframe(user_folder):
    """
    Crea un DataFrame con las imágenes en la carpeta, extrayendo el ID desde el nombre del archivo (ej. '12.jpg').
    Así se asegura que coincidan con el 'Image_ID' del Excel.
    """
    data = []

    for file in os.listdir(user_folder):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            try:
                # Extraer el número del nombre del archivo antes de la extensión
                image_id = int(os.path.splitext(file)[0])
                file_path = os.path.join(user_folder, file)

                data.append({
                    'Image_ID': image_id,
                    'Image': file_path
                })
            except ValueError:
                print(f"⚠️ El archivo '{file}' no tiene un nombre numérico válido. Se omitirá.")

    df = pd.DataFrame(data)
    df.sort_values("Image_ID", inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df




# Ahora, cuando se llame a create_full_dataframe(), Python ya conocerá create_dataframe()
def create_full_dataframe(username):
    user_folder, category_file = get_user_paths(username)

    df_images = create_dataframe(user_folder)  # Cargar imágenes con 'Image_ID' y 'Image'
    df_categories = load_categories_from_excel(category_file)  # Cargar categorías desde el Excel

    if df_images.empty:
        print("🚨 No se encontraron imágenes en la carpeta del usuario.")
        return pd.DataFrame()

    if df_categories.empty:
        print("🚨 No se encontraron categorías en el archivo Excel.")
        return pd.DataFrame()

    # 🔹 Asegurar que 'Image_ID' está presente en ambos DataFrames antes de fusionar
    if "Image_ID" not in df_categories.columns:
        print("🚨 Error: 'Image_ID' no está en el archivo de categorías.")
        return pd.DataFrame()

    # 🔹 Fusionar categorías con imágenes basadas en 'Image_ID'
    df_categories = df_categories.merge(df_images[['Image_ID', 'Image']], on="Image_ID", how="left")

    print(f"📌 Columnas en df después del merge: {df_categories.columns.tolist()}")

    # 🔹 Llenar valores nulos en caso de que alguna prenda no tenga imagen asociada
    df_categories.fillna({"Image": "No Image", "Type": "Unknown", "Color": "Unknown", "Weather": "All", "Style": "Casual", "Occasion": "Any"}, inplace=True)

    print(f"✅ Se han cargado {len(df_categories)} prendas en el DataFrame con imágenes.")

    return df_categories  # Retornar df_categories con la columna 'Image'

def estandarizar_marcas(df, marca_objetivo="By Paola Ospina"):
    """
    Limpia la columna 'Brand' y reemplaza variantes por el nombre oficial de la marca.
    """
    import unidecode
    df["Brand"] = df["Brand"].astype(str).apply(lambda x: unidecode.unidecode(x.strip().lower()))

    df["Brand"] = df["Brand"].apply(
        lambda x: marca_objetivo if "paola" in x and "ospina" in x else x.title()
    )

    return df

#_________________________________________________________

def get_state_vector(image_id, df):
    """
    Genera un vector de estado para el aprendizaje por refuerzo basado en las categorías esenciales y opcionales.
    """
    row = df[df["Image_ID"] == image_id]
    if row.empty:
        return [0] * 25  # Vector nulo si la imagen no existe (ajustado para el número total de características)

    row = row.iloc[0]  # Obtener la fila correspondiente

    # 🔹 Representación One-Hot Encoding para 'Type'
    type_encoding = {"Top": 0, "Bottom": 1, "Dress": 2, "Jacket": 3, "Hoodie": 4}
    type_vector = [0] * len(type_encoding)
    if row["Type"] in type_encoding:
        type_vector[type_encoding[row["Type"]]] = 1

    # 🔹 Representación One-Hot Encoding para 'Color' (puede contener múltiples valores separados por comas)
    color_encoding = {"White": 0, "Black": 1, "Red": 2, "Blue": 3, "Yellow": 4, "Purple": 5, 
                      "Orange": 6, "Green": 7, "Gray": 8, "Rose": 9, "Beige": 10, "Brown": 11}
    color_vector = [0] * len(color_encoding)
    for color in row["Color"].split(", "):
        if color in color_encoding:
            color_vector[color_encoding[color]] = 1

    # 🔹 Representación One-Hot Encoding para 'Style'
    style_encoding = {"Casual": 0, "Formal": 1, "Elegante": 2, "Urbano": 3}
    style_vector = [0] * len(style_encoding)
    for style in row["Style"].split(", "):
        if style in style_encoding:
            style_vector[style_encoding[style]] = 1

    # 🔹 Representación One-Hot Encoding para 'Occasion'
    occasion_encoding = {"Fiesta": 0, "Diario": 1, "Cena": 2, "Trabajo": 3}
    occasion_vector = [0] * len(occasion_encoding)
    for occasion in row["Occasion"].split(", "):
        if occasion in occasion_encoding:
            occasion_vector[occasion_encoding[occasion]] = 1

    # 🔹 Representación One-Hot Encoding para 'Weather'
    weather_encoding = {"Frío": 0, "Cálido": 1, "Todas": 2}
    weather_vector = [0] * len(weather_encoding)
    for weather in row["Weather"].split(", "):
        if weather in weather_encoding:
            weather_vector[weather_encoding[weather]] = 1

    # 🔹 Agregar características opcionales (Material, Fit, Length, Brand con mapeo básico)
    material_encoding = {"Lana": 1, "Poliéster": 2, "Seda": 3, "Algodón": 4,"Cuero": 5,"Jean": 6,"Licra": 7,"Lino": 8}
    fit_encoding = {"Regular": 1, "Ajustado": 2, "Oversized": 3}
    length_encoding = {"Corto": 1, "Largo": 2, "Medio": 3}
    brand_encoding = {"Nike": 1, "Adidas": 2, "Gucci": 3, "Todas": 4}

    material = material_encoding.get(row["Material"], 0)
    fit = fit_encoding.get(row["Fit"], 0)
    length = length_encoding.get(row["Length"], 0)
    brand = brand_encoding.get(row["Brand"], 0)

    # 🔹 Agregar peso de la prenda
    weight = row["Weight"] if "Weight" in row else 0.0

    # 🔹 Concatenar todo en un solo vector
    return type_vector + color_vector + style_vector + occasion_vector + weather_vector + [material, fit, length, brand, weight]

import unidecode  #pip install unidecode

def actualizar_diccionarios(df):
    """
    Revisa si hay nuevas etiquetas en las categorías que no están en los diccionarios.
    Si encuentra nuevas, las agrega automáticamente.
    Normaliza mayúsculas y tildes para la comparación.
    """
    import unidecode

    global type_encoding, color_encoding, style_encoding, occasion_encoding, weather_encoding
    global material_encoding, fit_encoding, length_encoding, brand_encoding

    diccionarios = {
        'Type': type_encoding,
        'Color': color_encoding,
        'Style': style_encoding,
        'Occasion': occasion_encoding,
        'Weather': weather_encoding,
        'Material': material_encoding,
        'Fit': fit_encoding,
        'Length': length_encoding,
        'Brand': brand_encoding
    }

    for categoria, encoding in diccionarios.items():
        print(f"\n🔍 Revisando categoría: {categoria}")
        valores = df[categoria].dropna().unique()

        for val in valores:
            subvalores = str(val).split(", ")
            for subvalor in subvalores:
                normalizado = unidecode.unidecode(subvalor.strip().lower())
                claves_normalizadas = [unidecode.unidecode(k.lower()) for k in encoding.keys()]
                if normalizado not in claves_normalizadas:
                    nuevo_index = max(encoding.values(), default=-1) + 1
                    encoding[subvalor.strip()] = nuevo_index
                    print(f"➕ Agregado '{subvalor.strip()}' a {categoria} (index {nuevo_index})")

    print("\n✅ Diccionarios actualizados.")


df = create_full_dataframe(username)
if 'Weight' not in df.columns:
    df['Weight'] = 0.0

# 🔥 Aquí llamas
actualizar_diccionarios(df)

# 🔧 PASO: estandarizar valores mal escritos en la columna Brand
def estandarizar_marcas(df, marca_objetivo="By Paola Ospina"):
    import unidecode
    df["Brand"] = df["Brand"].astype(str).apply(lambda x: unidecode.unidecode(x.strip().lower()))
    df["Brand"] = df["Brand"].apply(
        lambda x: marca_objetivo if "paola" in x and "ospina" in x else x.title()
    )
    return df

df = estandarizar_marcas(df)  # ✅ llama la función justo después de cargar df


def get_base_state(df):
    """
    Devuelve un vector de estado base (todo ceros) del mismo tamaño que los vectores de prenda.
    Se usa para representar el estado inicial del sistema.
    """
    if df.empty:
        raise ValueError("❌ DataFrame vacío. No se puede calcular el tamaño del vector base.")
    
    first_image_id = df.iloc[0]["Image_ID"]
    reference_vector = get_state_vector(first_image_id, df)
    return [0] * len(reference_vector)
     
    """
    #_____________________________________________________
    # 🔹 Pedir el nombre del usuario dinámicamente
    username = input("Ingrese su nombre de usuario: ").strip().lower()
    
    # Cargar el DataFrame final con el nombre ingresado
    df = create_full_dataframe(username)
    
    # 🔹 Asegurar que la columna 'Weight' existe antes de usarla
    if 'Weight' not in df.columns:
        df['Weight'] = 0.0  # Se inicializa en 0.0
    
    # Mostrar el DataFrame al usuario
    from IPython.display import display
    display(df)
    """
#_____________________________________________________________________________________________________________________________________________


# Columnas para el archivo de categorías
CATEGORY_COLUMNS = ["Image_ID", "Type", "Color", "Weather", "Style", "Occasion"]

# Función para crear el archivo de categorías si no existe
def create_category_file(category_file):
    if not os.path.exists(category_file):
        df = pd.DataFrame(columns=CATEGORY_COLUMNS)
        df.to_excel(category_file, index=False)
        print(f"📂 Archivo de categorías creado: {category_file}")
    else:
        print(f"✅ Archivo de categorías encontrado: {category_file}")

# Llamar a la función para asegurarnos de que el archivo existe
# Obtener las rutas dinámicamente antes de llamar la función
user_folder, category_file = get_user_paths(username)


# Llamar a la función pasando el archivo de categorías
create_category_file(category_file)
df = create_full_dataframe(username)
if 'Weight' not in df.columns:
    df['Weight'] = 0.0
actualizar_diccionarios(df)

####################################
print("📌 Estado inicial del DataFrame después de cargarlo en create_full_dataframe:")
print(df.head())  # Debe mostrar datos

#_________________________________________________________________________________________________________________________________________________

import requests

# Tu clave de API de OpenWeatherMap
API_KEY = "b438ae6755885d7b6944a6dba68f9519"  # 🚨 Reemplaza esto con tu clave real

# Función para obtener el clima actual en Bogotá
def get_weather():
    url = f"http://api.openweathermap.org/data/2.5/weather?q=Bogota,CO&appid={API_KEY}&units=metric"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        temperature = data["main"]["temp"]  # Temperatura actual en grados Celsius
        weather_condition = data["weather"][0]["main"]  # Ejemplo: "Clear", "Rain", "Clouds"
        return temperature, weather_condition
    else:
        print("🚨 Error al obtener los datos del clima.")
        return None, None

# Obtener y mostrar el clima actual
#temperature, weather_condition = get_weather()
#print(f"🌤️ Clima en Bogotá: {temperature}°C, {weather_condition}")


#_______________________________________________________________________________________________________________________________________________



# Inicializar Q-Table y parámetros de aprendizaje reforzado Q learning
q_table = {}  # Ahora almacenará claves tipo (tuple(state_vector), tuple(action_vector))
alpha, gamma, epsilon, decay_rate = 0.1, 0.9, 1.0, 0.995
feedback_db = []


# Función para guardar la Q-Table en Excel q learning
def save_q_table():
    if q_table:
        df_qtable = pd.DataFrame([(str(k[0]), str(k[1]), v) for k, v in q_table.items()],
                                 columns=["State", "Action", "Q-Value"])
        df_qtable.to_excel(q_table_path, index=False)
        print(f"✅ Q-Table guardada con vectores en: {q_table_path}")


# Función para cargar la Q-Table desde Excel
def load_q_table():
    global q_table
    if os.path.exists(q_table_path):
        df_qtable = pd.read_excel(q_table_path)
        
        if "State" in df_qtable.columns and "Action" in df_qtable.columns:
            # Versión avanzada (con vectores de estado y acción)
            q_table = {(eval(row["State"]), eval(row["Action"])): row["Q-Value"] for _, row in df_qtable.iterrows()}
            print("🔄 Q-Table cargada con vectores (State, Action).")
        elif "Outfit_IDs" in df_qtable.columns and "Q-Value" in df_qtable.columns:
            # Versión básica (solo texto de combinación)
            print("⚠️ Q-Table actual solo contiene texto de outfits. No se puede reconstruir automáticamente.")
            q_table = {}  # Vacía para evitar error
        else:
            print("🚨 Formato no reconocido en el archivo de Q-Table.")

# Llamamos a la carga de la Q-Table al iniciar el código
load_q_table()

print(f"🔁 Q-Table cargada con {len(q_table)} combinaciones aprendidas.")


# Actualizar la Q-Table para ecuacion q learning
def update_q_table_full_outfit(outfit, reward, df):
    """
    Actualiza la Q-table usando todo el outfit como una acción completa.
    El estado base es fijo (por ejemplo, un vector de ceros).
    """
    base_state = tuple(get_base_state(df))
    action_vector = []

    for item in outfit:
        vec = get_state_vector(item["Image_ID"], df)
        action_vector.extend(vec)

    action_vector = tuple(action_vector)

    current_q = q_table.get((base_state, action_vector), 0)
    new_q = current_q + alpha * (reward - current_q)
    q_table[(base_state, action_vector)] = new_q

    save_q_table()


# Generar outfits usando Q-Learning con combinaciones coherentes___________________________________________________________________________________
# Asumiendo que ya tienes el feedback almacenado en feedback_db

def adjust_recent_limit(feedback_db, recent_limit):
    """
    Ajusta dinámicamente el límite de prendas recientes basándose en el feedback.
    Si el usuario ha dado más likes, aumenta el límite de prendas que pueden repetirse.
    Si el feedback es negativo, disminuye el límite para evitar la repetición de prendas no gustadas.
    """
    if not feedback_db:
        return recent_limit  # Si no hay feedback, no ajustamos

    # Calculamos la tasa de feedback positivo
    positive_feedback = sum(1 for f in feedback_db if f['Reward'] == 1)
    total_feedback = len(feedback_db)
    success_rate = positive_feedback / total_feedback if total_feedback else 0

    # Ajuste del límite basado en la tasa de éxito del feedback
    if success_rate > 0.7:  # Mucho feedback positivo
        recent_limit = min(20, recent_limit + 1)  # Max 20 como ejemplo
    elif success_rate < 0.3:  # Mucho feedback negativo
        recent_limit = max(5, recent_limit - 1)  # Min 5 como ejemplo
    else:
        recent_limit = max(5, recent_limit)  # No dejar que baje de 5

    print(f"🧪 Nuevo límite de prendas recientes: {recent_limit} con tasa de éxito del {success_rate*100:.2f}%")
    return recent_limit


# Usar la función en tu ciclo de generación de outfits####################################################################################
recent_combinations = []
recent_limit = 10  # valor inicial, luego dinámico según feedback

#________________________________________________________________________________________________________________________________________
# Numero de outfits generados
def generate_outfits(num_outfits=3):
    global evaluar_marca

    outfits = []
    attempts = 0
    max_attempts = 200

    df_available = df[df["Image"].apply(os.path.exists)]

    if evaluar_marca:
        import unidecode
        marca_normalizada = unidecode.unidecode(marca_objetivo.lower())
        df_available["Brand_norm"] = df_available["Brand"].astype(str).apply(
            lambda x: unidecode.unidecode(x.strip().lower())
        )

        prendas_marca = df_available[df_available["Brand_norm"].str.contains(marca_normalizada, na=False)]

        if prendas_marca.empty:
            print("⚠️ No hay prendas de la marca disponibles. Se generarán outfits sin restricción de marca.")
            evaluar_marca = False

        df_available.drop(columns=["Brand_norm"], inplace=True)


    outfit_types = [
        ['Top', 'Bottom'],
        ['Jacket', 'Top', 'Bottom'],
        ['Jacket', 'Dress'],
        ['Hoodie', 'Bottom'],
        ['Hoodie', 'Dress']
    ]

    while len(outfits) < num_outfits and attempts < max_attempts:
        attempts += 1
        combo = random.choice(outfit_types)
        outfit = []
        tipos_necesarios = combo.copy()
        used_ids = []

        for tipo in tipos_necesarios:
            candidatos = df_available[(df_available["Type"] == tipo)]
            candidatos = candidatos[~candidatos["Image_ID"].isin(used_ids)]

            if candidatos.empty:
                break

            prenda = candidatos.sample(1).iloc[0]
            outfit.append(prenda.to_dict())
            used_ids.append(prenda["Image_ID"])

        if len(outfit) != len(combo):
            continue  # Outfit incompleto, lo descartamos

        # 🚫 Evitar repeticiones exactas
        outfit_ids = tuple(sorted([p["Image_ID"] for p in outfit]))
        if outfit_ids in recent_combinations:
            continue

        # ✅ Validar que haya al menos una prenda de la marca si se está evaluando
        if evaluar_marca:
            tiene_marca = any(p.get("Brand") == marca_objetivo for p in outfit)
            if not tiene_marca:
                continue  # Outfit no cumple con la condición de la marca

        # ✅ Si pasa todas las validaciones, lo añadimos
        outfits.append(outfit)
        recent_combinations.append(outfit_ids)
        if len(recent_combinations) > recent_limit:
            recent_combinations.pop(0)

    if not outfits:
        print("⚠️ No se pudieron generar outfits variados con las prendas actuales.")
    return outfits

#________________________________________________________________________________________________________________________________________

# Mostrar outfits con imágenes 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

def display_outfits(outfits, df):
    """
    Muestra los outfits generados con las imágenes reales y en orden:
    Jacket → Hoodie → Top → Bottom → Dress.
    Si falta una imagen, avisa cuál es y no la muestra.
    """
    num_outfits = len(outfits)
    max_layers = max(len(outfit) for outfit in outfits)
    fig, axes = plt.subplots(max_layers, num_outfits, figsize=(12, 10), squeeze=False)

    for col, outfit in enumerate(outfits):
        image_ids = [item['Image_ID'] for item in outfit]
        outfit_data = df[df['Image_ID'].isin(image_ids)].drop_duplicates(subset=['Image_ID'])

        # Organizar las prendas en orden correcto
        type_order = ["Jacket", "Hoodie", "Top", "Bottom", "Dress"]
        ordered_outfit = []
        for tipo in type_order:
            prendas = outfit_data[outfit_data["Type"] == tipo]
            if not prendas.empty:
                ordered_outfit.append(prendas.iloc[0])

        # Mostrar las prendas
        for row, item in enumerate(ordered_outfit):
            image_path = item["Image"]
            image_id = item["Image_ID"]
            tipo = item["Type"]
            color = item["Color"]
            brand = item.get("Brand", "")

            if os.path.exists(image_path):
                img = mpimg.imread(image_path)
                axes[row, col].imshow(img)
                if brand == "By Paola Ospina":
                    axes[row, col].set_title(f"{tipo} - {brand}\n({color})", fontsize=8)
                else:
                    axes[row, col].set_title(f"{tipo} ({color})", fontsize=9)


            else:
                axes[row, col].text(0.5, 0.5, f"Sin Imagen\nID: {image_id}", ha='center', va='center', 
                                    fontsize=9, color='red')
                axes[row, col].set_title(f"{tipo}", fontsize=9)
                print(f"🚨 Imagen no encontrada para ID: {image_id} → {image_path}")

            axes[row, col].axis('off')

        # Ocultar filas vacías si el outfit tiene menos capas
        for empty_row in range(len(ordered_outfit), max_layers):
            axes[empty_row, col].axis('off')

    plt.tight_layout()
    plt.show()

#_________________________________________________________________________________________________________________________________________


def get_next_state(action_vector, df):
    """
    Selecciona el siguiente estado basado en la política de exploración/explotación
    utilizando la Q-Table y los nuevos vectores de estado.
    """
    possible_actions = df["Image_ID"].values  # Lista de imágenes disponibles

    if not possible_actions.any():
        return None  # No hay imágenes para elegir

    # Convertimos los Image_ID en vectores de estado
    action_states = [get_state_vector(img_id, df) for img_id in possible_actions]

    # Exploración aleatoria si no hay datos en la Q-Table
    if random.uniform(0, 1) < epsilon or not any((tuple(a) in q_table) for a in action_states):
        return random.choice(action_states)

    # Seleccionar la mejor acción basada en los valores Q
    q_values = [q_table.get((tuple(action_vector), tuple(a)), 0) for a in action_states]
    best_action = action_states[np.argmax(q_values)]

    return best_action

def registrar_feedback_detallado(outfit, reward, fuente, outfit_id, df, feedback_db):
    """
    Guarda feedback detallado por cada prenda del outfit, incluyendo marca, tipo, color, y la fuente (Humano o Modelo).
    """
    for prenda in outfit:
        image_id = prenda.get('Image_ID')
        fila = df[df["Image_ID"] == image_id]

        if fila.empty:
            print(f"⚠️ No se encontró la prenda con ID {image_id} en el DataFrame.")
            continue

        fila = fila.iloc[0]
        feedback_db.append({
            'Outfit_ID': outfit_id,
            'Image_ID': image_id,
            'Type': fila.get('Type', 'Unknown'),
            'Brand': fila.get('Brand', 'Unknown'),
            'Color': fila.get('Color', 'Unknown'),
            'Reward': reward,
            'Fuente': fuente,
            'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        })

#___________________________________________
def tasa_aceptacion_marca(feedback_input, marca_objetivo="By Paola Ospina"):
    """
    Calcula la tasa de aceptación (likes) para una marca específica.
    Acepta tanto un DataFrame como una lista de diccionarios.
    """
    # Convertir a DataFrame si es lista
    if isinstance(feedback_input, list):
        feedback_df = pd.DataFrame(feedback_input)
    elif isinstance(feedback_input, pd.DataFrame):
        feedback_df = feedback_input
    else:
        print("❌ Formato de feedback no válido.")
        return 0.0

    if feedback_df.empty:
        print("📭 No hay feedback disponible.")
        return 0.0

    prendas_marca = feedback_df[feedback_df["Brand"] == marca_objetivo]
    if prendas_marca.empty:
        print(f"❗ No hay feedback registrado para la marca {marca_objetivo}")
        return 0.0

    positivos = (prendas_marca["Reward"] == 1).sum()
    tasa = positivos / len(prendas_marca)
    print(f"💖 Tasa de aceptación para '{marca_objetivo}': {tasa*100:.2f}%")
    return tasa

# Recolectar feedback y actualizar la Q-Table q learning----------------------------------------
def rate_outfits(outfits):
    """
    Permite al usuario calificar cada outfit con 1 (Me gusta) o 0 (No me gusta) 
    y ajusta la Q-Table y el feedback detallado.
    """
    global epsilon  

    for idx, outfit in enumerate(outfits):
        while True:
            try:
                rating = int(input(f"💬 Califica el Outfit {idx + 1} {[item['Image_ID'] for item in outfit]} (1=Me gusta, 0=No me gusta): "))
                if rating not in [0, 1]:
                    raise ValueError("Debes ingresar 1 o 0.")
                break
            except ValueError as e:
                print(e)

        reward = 1 if rating == 1 else -1

        # 🔹 Guardar feedback detallado
        registrar_feedback_detallado(outfit, reward, "Humano", idx + 1, df, feedback_db)
        # 🔹 NUEVO: Actualizar Q-Table con el outfit completo como acción
        update_q_table_full_outfit(outfit, reward, df)

        # 🔹 Actualizar Q-Table por transiciones (state → action)
        for i in range(len(outfit) - 1):
            state = outfit[i]['Image_ID']
            action = outfit[i + 1]['Image_ID']

            current_state_vector = get_state_vector(state, df)
            next_state_vector = get_state_vector(action, df)
            next_state = get_next_state(next_state_vector, df)

            current_q = q_table.get((tuple(current_state_vector), tuple(next_state_vector)), 0)
            max_next_q = max([
                q_table.get((tuple(next_state), tuple(get_state_vector(a, df))), 0)
                for a in df['Image_ID']
            ], default=0)

            new_q = current_q + alpha * (reward + gamma * max_next_q - current_q)
            q_table[(tuple(current_state_vector), tuple(next_state_vector))] = new_q

        # 🔹 Ajustar pesos
        for item in outfit:
            if 'Image_ID' in item:
                df.loc[df['Image_ID'] == item['Image_ID'], 'Weight'] += 0.1 if rating == 1 else -0.1
                df['Weight'] = df['Weight'].clip(lower=0)

    save_q_table()

    # 🔁 Ajuste de exploración/explotación (epsilon)
    total_feedback = len(feedback_db)
    positive_feedback = sum(1 for f in feedback_db if f['Reward'] == 1)

    if total_feedback > 0:
        success_rate = positive_feedback / total_feedback
        if success_rate > 0.7:
            epsilon = max(0.1, epsilon * 0.95)
        elif success_rate < 0.3:
            epsilon = min(1.0, epsilon * 1.05)
        else:
            epsilon = max(0.1, epsilon * decay_rate)

    print(f"🔄 Tasa de exploración actualizada: ε = {epsilon:.4f}")
    save_params()  # 🔥 Guarda el epsilon actualizado
    
    # 💖 Mostrar tasa de aceptación de la marca
    tasa = tasa_aceptacion_marca(feedback_db, marca_objetivo)
    print(f"💖 Tasa de aceptación para '{marca_objetivo}': {tasa*100:.2f}%")
    

###################################
# Justo antes de usar df en generate_outfits()
if df.empty:
    print("🚨 ERROR: df está vacío antes de generar outfits.")
else:
    print("✅ df contiene datos antes de generar outfits:")
    print(df.head())

#######################################

### exportar DB
from datetime import datetime

def guardar_feedback_csv(feedback_db, ruta_csv):
    feedback_df = pd.DataFrame(feedback_db)
    fecha_actual = datetime.now().strftime("%Y-%m-%d")
    hora_actual = datetime.now().strftime("%H:%M:%S")
    
    global resumen_df
    resumen_df = pd.DataFrame({
        "Descripción": ["Fecha de la sesión", "Hora de la sesión", "Total de interacciones"],
        "Valor": [fecha_actual, hora_actual, len(feedback_db)]
    })

    if not feedback_df.empty:
        timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        ruta_completa = ruta_csv.replace(".csv", f"_{timestamp}.csv")
        feedback_df.to_csv(ruta_completa, index=False)
        print(f"📁 Feedback guardado como CSV en: {ruta_completa}")

#FEEDBACK ACUMULADO
def cargar_feedback_acumulado(feedback_dir):
    """
    Carga todos los archivos feedback_*.csv del usuario (históricos y actuales),
    los fusiona, elimina duplicados y devuelve un DataFrame único.
    """
    feedback_files = glob.glob(os.path.join(feedback_dir, "feedback_*.csv"))
    if not feedback_files:
        print("📭 No hay archivos de feedback.")
        return pd.DataFrame()

    lista_dfs = []
    for archivo in feedback_files:
        try:
            df = pd.read_csv(archivo)
            lista_dfs.append(df)
        except Exception as e:
            print(f"❌ Error leyendo {archivo}: {e}")

    feedback_total = pd.concat(lista_dfs, ignore_index=True)
    feedback_total.drop_duplicates(subset=["Outfit_ID", "Image_ID", "Timestamp"], inplace=True)
    print(f"📦 Feedback acumulado cargado: {len(feedback_total)} entradas únicas.")
    return feedback_total


#######################################

# Ciclo principal de evaluación de outfits
# Evaluación de outfits
def evaluate_outfits():
    global recent_limit  # Importante: para poder modificar la variable global
    while True:
        outfits = generate_outfits(num_outfits=5)####################################################################################################

        if not outfits:
            print("🚨 No se generaron outfits.")
            continue  

        display_outfits(outfits, df)
        rate_outfits(outfits)


        # Aquí ajustamos recent_limit dinámicamente después del feedback del usuario
        recent_limit = adjust_recent_limit(feedback_db, recent_limit)

        if input("¿Quieres evaluar más outfits? (s/n): ").strip().lower() != 's':
            print("Gracias por evaluar los outfits. ¡Hasta luego!")
            break


# Cargar feedback del usuario actual desde su carpeta
feedback_files = glob.glob(os.path.join(feedback_dir, "feedback_*.csv"))  # 🧠 Ya apunta a la carpeta del usuario

if feedback_files:
    # 🔄 Cargar todos los CSVs de feedback encontrados
    dfs = [pd.read_csv(f) for f in feedback_files]
    feedback_hist = pd.concat(dfs, ignore_index=True)

    print(f"📈 Feedback histórico cargado: {len(feedback_hist)} interacciones (antes de limpieza).")

    # 🧼 Eliminar duplicados basados en Outfit, Imagen y Timestamp
    feedback_hist.drop_duplicates(subset=["Outfit_ID", "Image_ID", "Timestamp"], inplace=True)

    print(f"✅ Feedback único conservado: {len(feedback_hist)} entradas tras limpieza.")

    # 🔁 Asignar a la base actual
    feedback_db = feedback_hist.to_dict('records')
else:
    print("📭 No se encontró feedback previo del usuario.")


if feedback_files:
    # 🔄 Cargar todos los CSVs de feedback encontrados
    dfs = [pd.read_csv(f) for f in feedback_files]
    feedback_hist = pd.concat(dfs, ignore_index=True)

    print(f"📈 Feedback histórico cargado: {len(feedback_hist)} interacciones (antes de limpieza).")

    # 🧼 Eliminar duplicados basados en Outfit, Imagen y Timestamp
    feedback_hist.drop_duplicates(subset=["Outfit_ID", "Image_ID", "Timestamp"], inplace=True)

    print(f"✅ Feedback único conservado: {len(feedback_hist)} entradas tras limpieza.")

    # 🔁 Asignar a la base actual
    feedback_db = feedback_hist.to_dict('records')

# Ejecutar el sistema de recomendación
evaluate_outfits()

# Guardar feedback como CSV
ruta_feedback_csv = os.path.join(feedback_dir, "feedback.csv")
guardar_feedback_csv(feedback_db, ruta_feedback_csv)

def contar_outfits_totales(ruta_feedback_csv):
    """
    Cuenta cuántos outfits únicos se han registrado en feedback.csv
    """
    if not os.path.exists(ruta_feedback_csv):
        print("📭 No existe feedback.csv aún.")
        return 0
    df = pd.read_csv(ruta_feedback_csv)
    total = df['Outfit_ID'].nunique()
    print(f"📊 Total de outfits generados y guardados: {total}")
    return total



def plot_learning_curve(guardar_imagen=False, ruta_imagen=None):
    """
    Genera la curva de aprendizaje basada en la recompensa acumulada.
    Agrega una curva suavizada (rolling mean) y anota el punto máximo.
    Puede guardar la imagen si se desea.
    """
    if not feedback_db:
        print("⚠️ No hay feedback disponible para graficar la curva de aprendizaje.")
        return

    # Crear DataFrame ordenado
    df_feedback = pd.DataFrame(feedback_db)
    df_feedback["Timestamp"] = pd.to_datetime(df_feedback["Timestamp"])
    df_feedback = df_feedback.sort_values("Timestamp").reset_index(drop=True)

    # 🔹 Agregar número de iteración y recompensa acumulada
    df_feedback["Iteración"] = df_feedback.index
    df_feedback["Recompensa Acumulada"] = df_feedback["Reward"].cumsum()

    # 🔹 Suavizar la curva con media móvil
    df_feedback["Tendencia"] = df_feedback["Recompensa Acumulada"].rolling(window=10).mean()

    # 🔹 Plot principal
    plt.figure(figsize=(10, 5))
    plt.plot(df_feedback["Iteración"], df_feedback["Recompensa Acumulada"],
             color='darkblue', marker='o', linewidth=2, label="Recompensa acumulada")

    # 🔹 Añadir curva suavizada
    plt.plot(df_feedback["Iteración"], df_feedback["Tendencia"],
             color='orange', linestyle='--', linewidth=2, label="Tendencia (media móvil)")

    # 🔹 Anotar punto máximo
    max_idx = df_feedback["Recompensa Acumulada"].idxmax()
    max_val = df_feedback.loc[max_idx]
    plt.annotate("🎯 Máximo",
                 xy=(max_val["Iteración"], max_val["Recompensa Acumulada"]),
                 xytext=(max_val["Iteración"] + 10, max_val["Recompensa Acumulada"] + 5),
                 arrowprops=dict(arrowstyle="->", color='gray'))

    # 🔹 Etiquetas y estilos
    plt.title("📈 Curva de Aprendizaje del Sistema")
    plt.xlabel("Iteración")
    plt.ylabel("Recompensa acumulada")
    plt.grid(True)
    plt.legend()

    if guardar_imagen and ruta_imagen:
        plt.savefig(ruta_imagen, bbox_inches='tight')
        print(f"🖼️ Curva de aprendizaje guardada como imagen en: {ruta_imagen}")

    plt.show()


# Llamar a la función de visualización después de evaluar los outfits
plot_learning_curve()


### ACEPTACION DE MARCA Y CURVA DEL DIA--------------------------------------------------------------------------------
import glob
import os

# Ruta base donde guardas el feedback
feedback_dir = r"C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\OUTPUT_CODIGO"
feedback_files = glob.glob(os.path.join(feedback_dir, "feedback_*.csv"))

# Obtener el archivo más reciente
ruta_feedback = max(feedback_files, key=os.path.getctime)
print(f"📂 Cargando archivo más reciente: {ruta_feedback}")
# Cargar el feedback más reciente como DataFrame
feedback_df = pd.read_csv(ruta_feedback)
feedback_df["Timestamp"] = pd.to_datetime(feedback_df["Timestamp"], errors='coerce')
feedback_df["Fecha"] = feedback_df["Timestamp"].dt.date


# -----------------------------------------------------------------------------
# ✅ 2. GRÁFICO DE ACEPTACIÓN POR OUTFIT (% de likes por Outfit_ID)
# -----------------------------------------------------------------------------
aceptacion_por_outfit = feedback_df.groupby("Outfit_ID")["Reward"].mean() * 100
plt.figure(figsize=(10, 4))
plt.bar(aceptacion_por_outfit.index.astype(str), aceptacion_por_outfit.values)
plt.xticks(rotation=90)
plt.title("💬 Porcentaje de aceptación por outfit")
plt.ylabel("% Me gusta")
plt.xlabel("Outfit ID")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# -----------------------------------------------------------------------------
# 👗 3. TOP PRENDAS MÁS LIKED – GENERAL
# -----------------------------------------------------------------------------
likes = feedback_df[feedback_df["Reward"] == 1]
top_general = likes.groupby(["Image_ID", "Type", "Brand"]).size().reset_index(name="Likes")
top_general = top_general.sort_values("Likes", ascending=False).head(10)

import matplotlib.image as mpimg

# Filtrar prendas con reward positivo
likes_df = feedback_df[feedback_df["Reward"] == 1]

# Contar likes por Image_ID
top_likes = likes_df.groupby("Image_ID").size().sort_values(ascending=False).head(5).reset_index(name="Likes")

# Unir con df para obtener ruta de imagen y detalles
top_with_images = top_likes.merge(df[["Image_ID", "Image", "Brand", "Type", "Color"]], on="Image_ID", how="left")

# Mostrar imágenes de las prendas más liked
fig, axes = plt.subplots(1, len(top_with_images), figsize=(15, 4))

for i, (_, row) in enumerate(top_with_images.iterrows()):
    img_path = row["Image"]
    try:
        img = mpimg.imread(img_path)
        axes[i].imshow(img)
        axes[i].axis('off')
        axes[i].set_title(f'ID {row["Image_ID"]}\n{row["Type"]} - {row["Likes"]} Likes', fontsize=8)
    except Exception:
        axes[i].text(0.5, 0.5, "❌ Imagen no encontrada", ha='center', va='center', fontsize=9)
        axes[i].set_title(f'ID {row["Image_ID"]}', fontsize=9)
        axes[i].axis('off')

plt.tight_layout()
plt.show()
# PRENDAS BY PAOLA OSPINA
Para este codigo pongo las 3 mas gustadas?

# 🎀 Mostrar top prendas más liked de la marca "By Paola Ospina"
likes_marca = feedback_df[(feedback_df["Reward"] == 1) & (feedback_df["Brand"] == "By Paola Ospina")]
top_marca_likes = likes_marca.groupby("Image_ID").size().sort_values(ascending=False).head(3).reset_index(name="Likes")#.head cantidad de prendas eneste caso las 3 mas gustadas
top_marca_images = top_marca_likes.merge(df[["Image_ID", "Image", "Brand", "Type", "Color"]], on="Image_ID", how="left")

if not top_marca_images.empty:
    fig, axes = plt.subplots(1, len(top_marca_images), figsize=(15, 4))
    for i, (_, row) in enumerate(top_marca_images.iterrows()):
        img_path = row["Image"]
        try:
            img = mpimg.imread(img_path)
            axes[i].imshow(img)
            axes[i].axis('off')
            axes[i].set_title(f'{row["Type"]}\n{row["Likes"]} Likes', fontsize=8)
        except Exception:
            axes[i].text(0.5, 0.5, "❌ Imagen no encontrada", ha='center', va='center')
            axes[i].axis('off')
    plt.suptitle("✨ Top prendas de 'By Paola Ospina'", fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Aún no hay prendas de la marca con likes registrados.")

# -----------------------------------------------------------------------------
# 👗 4. TOP PRENDAS DE LA MARCA 'By Paola Ospina'
# -----------------------------------------------------------------------------
top_marca = top_general[top_general["Brand"] == "By Paola Ospina"].head(5)

if not top_marca.empty:
    plt.figure(figsize=(8, 4))
    plt.bar(top_marca["Image_ID"].astype(str), top_marca["Likes"], color='lightgreen')
    plt.title("✨ Prendas más liked de 'By Paola Ospina'")
    plt.xlabel("Image_ID")
    plt.ylabel("Likes")
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
else:
    print("❗ Aún no hay prendas de la marca con likes registrados.")


# ====================== MÉTRICAS Y KPIs ==========================

def calcular_precision(feedback_db):
    if not feedback_db:
        return 0
    total = len(feedback_db)
    positivos = sum(1 for f in feedback_db if f['Reward'] == 1)
    precision = positivos / total
    print(f"🎯 Precisión del modelo: {precision * 100:.2f}%")
    return precision


def calcular_satisfaccion(feedback_db):
    if not feedback_db:
        return 0
    positivos = sum(1 for f in feedback_db if f['Reward'] == 1)
    satisfaction = positivos / len(feedback_db)
    print(f"😊 Satisfacción del usuario: {satisfaction * 100:.2f}%")
    return satisfaction

def mostrar_prendas_populares(df):
    print("\n👗 Prendas más usadas:")
    print(df.sort_values("Weight", ascending=False)[["Image_ID", "Type", "Color", "Weight"]].head(5))

    print("\n🧥 Prendas menos usadas:")
    print(df.sort_values("Weight")[["Image_ID", "Type", "Color", "Weight"]].head(5))


"""
def graficar_colores_populares(df):
    color_counts = df['Color'].str.split(', ').explode().value_counts()

    plt.figure(figsize=(10, 5))
    color_counts.plot(kind='bar')
    plt.title("🎨 Colores más frecuentes en el sistema")
    plt.ylabel("Cantidad de prendas")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(True)
    plt.show()
"""

print("\n--- KPIs del Sistema ---")
calcular_precision(feedback_db)
calcular_satisfaccion(feedback_db)
tasa_aceptacion_marca(feedback_db, marca_objetivo)
#mostrar_prendas_populares(df)
#graficar_colores_populares(df)


def guardar_kpis_en_excel(feedback_db, df, ruta_salida):
    precision = calcular_precision(feedback_db)
    satisfaccion = calcular_satisfaccion(feedback_db)
    aceptacion_marca = tasa_aceptacion_marca(feedback_db, marca_objetivo)

    # Prendas más y menos usadas
    top_usadas = df.sort_values("Weight", ascending=False)[["Image_ID", "Type", "Color", "Weight"]].head(5)
    menos_usadas = df.sort_values("Weight")[["Image_ID", "Type", "Color", "Weight"]].head(5)

    # Guardar todo en un Excel con múltiples hojas
    with pd.ExcelWriter(ruta_salida) as writer:
        # ✅ CORRECTO: ahora todo está dentro del with
        kpi_df = pd.DataFrame([
            {"Métrica": "Precisión", "Valor": f"{precision:.2%}"},
            {"Métrica": "Satisfacción", "Valor": f"{satisfaccion:.2%}"},
            {"Métrica": f"Aceptación '{marca_objetivo}'", "Valor": f"{aceptacion_marca:.2%}"}
        ])
        kpi_df.to_excel(writer, sheet_name="KPIs", index=False)

        top_usadas.to_excel(writer, sheet_name="Más usadas", index=False)
        menos_usadas.to_excel(writer, sheet_name="Menos usadas", index=False)

        print(f"📂 KPIs guardados exitosamente en: {ruta_salida}")


# Guardar KPIs en un archivo de Excel
guardar_kpis_en_excel(feedback_db, df, ruta_kpis)

#CURVA D EAPRENDIZAJE POR OUTFIT 
def plot_learning_curve_por_outfit(feedback_db):
    """
    📈 Nueva curva de aprendizaje basada en evaluaciones por Outfit_ID (no por prenda individual).
    """
    if not feedback_db:
        print("⚠️ No hay feedback disponible para graficar la curva por outfit.")
        return

    # Crear DataFrame
    df_feedback = pd.DataFrame(feedback_db)
    df_feedback["Timestamp"] = pd.to_datetime(df_feedback["Timestamp"])
    df_feedback = df_feedback.sort_values("Timestamp").reset_index(drop=True)

    # Agrupar por Outfit_ID y tomar el reward promedio (asumiendo que el usuario evalúa el outfit completo)
    outfit_feedback = df_feedback.groupby("Outfit_ID")["Reward"].mean().reset_index()

    # Cálculo de recompensa acumulada por Outfit
    outfit_feedback["Iteración"] = outfit_feedback.index
    outfit_feedback["Recompensa Acumulada"] = outfit_feedback["Reward"].cumsum()

    # 🔹 Suavizado
    outfit_feedback["Tendencia"] = outfit_feedback["Recompensa Acumulada"].rolling(window=5).mean()

    # 🔹 Plot
    plt.figure(figsize=(10, 5))
    plt.plot(outfit_feedback["Iteración"], outfit_feedback["Recompensa Acumulada"],
             color='green', marker='o', linewidth=2, label="Recompensa acumulada por outfit")


    plt.title("📈 Curva de Aprendizaje Basada en Outfits")
    plt.xlabel("Outfit evaluado")
    plt.ylabel("Recompensa acumulada")
    plt.grid(True)
    plt.legend()
    plt.show()

def calcular_aceptacion_marca(feedback_db, marca_objetivo="By Paola Ospina"):
    if not feedback_db:
        return 0.0
    marca_feedback = [f for f in feedback_db if f.get("Brand") == marca_objetivo]
    if not marca_feedback:
        return 0.0
    positivos = sum(1 for f in marca_feedback if f['Reward'] == 1)
    return positivos / len(marca_feedback)


# DAHSBOARD #_######################################
def exportar_dashboard_completo(df, q_table, feedback_db, ruta_excel, ruta_imagen=None):
    # Convertir Q-table en DataFrame
    q_df = pd.DataFrame([(k[0], k[1], v) for k, v in q_table.items()],
                        columns=["State", "Action", "Q-Value"])
    q_df = q_df.sort_values("Q-Value", ascending=False).head(50)

    # KPIs
    precision = calcular_precision(feedback_db)
    satisfaccion = calcular_satisfaccion(feedback_db)
    aceptacion_marca = tasa_aceptacion_marca(feedback_db, marca_objetivo)
    total_interacciones = len(feedback_db)


    kpi_df = pd.DataFrame({
        "Métrica": ["Precisión", "Satisfacción", f"Aceptación '{marca_objetivo}'", "Total de Interacciones"],
        "Valor": [f"{precision:.2%}", f"{satisfaccion:.2%}", f"{aceptacion_marca:.2%}", total_interacciones]
    })


    top_usadas = df.sort_values("Weight", ascending=False)[["Image_ID", "Type", "Color", "Weight"]].head(5)
    menos_usadas = df.sort_values("Weight")[["Image_ID", "Type", "Color", "Weight"]].head(5)
    feedback_df = pd.DataFrame(feedback_db)

    with pd.ExcelWriter(ruta_excel, engine='xlsxwriter') as writer:
        kpi_df.to_excel(writer, sheet_name="KPIs", index=False)
        top_usadas.to_excel(writer, sheet_name="Más Usadas", index=False)
        menos_usadas.to_excel(writer, sheet_name="Menos Usadas", index=False)
        q_df.to_excel(writer, sheet_name="Q-Table", index=False)
        feedback_df.to_excel(writer, sheet_name="Feedback", index=False)

        # Insertar imagen si existe
        if ruta_imagen and os.path.exists(ruta_imagen):
            workbook = writer.book
            worksheet = workbook.add_worksheet("Curva Aprendizaje")
            writer.sheets["Curva Aprendizaje"] = worksheet
            worksheet.insert_image("B2", ruta_imagen)

        resumen_df.to_excel(writer, sheet_name="Resumen", index=False)
        
        print(f"📊 Dashboard exportado exitosamente en: {ruta_excel}")
# Out:
# 🔐 Ingrese el nombre del usuario:  paola
# 🔁 Parámetros de aprendizaje cargados desde archivo.
# ✅ Archivo de categorías encontrado: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\categorias_paola.xlsx
# ✅ 104 prendas cargadas para el usuario 'paola'
# 📈 Feedback cargado: 57 entradas.
# 🔄 Q-Table cargada con 56 combinaciones.
# 🚀 Inicialización completa para: paola
# ✅ Categorías cargadas exitosamente desde C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\categorias_paola.xlsx
# 📌 Columnas en df después del merge: ['Image_ID', 'Type', 'Color', 'Style', 'Occasion', 'Material', 'Fit', 'Length', 'Weather', 'Brand', 'Image']
# ✅ Se han cargado 104 prendas en el DataFrame con imágenes.
#
# 🔍 Revisando categoría: Type
#
# 🔍 Revisando categoría: Color
# ➕ Agregado 'Grey' a Color (index 12)
#
# 🔍 Revisando categoría: Style
#
# 🔍 Revisando categoría: Occasion
#
# 🔍 Revisando categoría: Weather
# ➕ Agregado 'Calor' a Weather (index 3)
#
# 🔍 Revisando categoría: Material
#
# 🔍 Revisando categoría: Fit
#
# 🔍 Revisando categoría: Length
#
# 🔍 Revisando categoría: Brand
# ➕ Agregado 'Seven and seven' a Brand (index 5)
# ➕ Agregado 'ELA' a Brand (index 6)
# ➕ Agregado 'Adiddas' a Brand (index 7)
# ➕ Agregado 'Hollister' a Brand (index 8)
# ➕ Agregado 'By Paola Ospina' a Brand (index 9)
#
# ✅ Diccionarios actualizados.
# ✅ Archivo de categorías encontrado: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\categorias_paola.xlsx
# ✅ Categorías cargadas exitosamente desde C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\categorias_paola.xlsx
# 📌 Columnas en df después del merge: ['Image_ID', 'Type', 'Color', 'Style', 'Occasion', 'Material', 'Fit', 'Length', 'Weather', 'Brand', 'Image']
# ✅ Se han cargado 104 prendas en el DataFrame con imágenes.
#
# 🔍 Revisando categoría: Type
#
# 🔍 Revisando categoría: Color
#
# 🔍 Revisando categoría: Style
#
# 🔍 Revisando categoría: Occasion
#
# 🔍 Revisando categoría: Weather
#
# 🔍 Revisando categoría: Material
#
# 🔍 Revisando categoría: Fit
#
# 🔍 Revisando categoría: Length
#
# 🔍 Revisando categoría: Brand
#
# ✅ Diccionarios actualizados.
# 📌 Estado inicial del DataFrame después de cargarlo en create_full_dataframe:
#    Image_ID    Type  Color                     Style  \
# 0         1  Bottom  Beige  Formal, Casual, Elegante
# 1         2  Bottom  Black  Formal, Casual, Elegante
# 2         3  Bottom  Black  Formal, Casual, Elegante
# 3         4  Bottom  Black          Formal, Elegante
# 4         5  Bottom  Black  Formal, Casual, Elegante
#
#                         Occasion   Material        Fit Length Weather  \
# 0          Diario, Cena, Trabajo       Lana   Ajustado  Largo    Frío
# 1          Diario, Cena, Trabajo       Lana   Ajustado  Largo   Todas
# 2          Diario, Cena, Trabajo  Poliéster  Oversized  Largo   Todas
# 3           Diario, Cena, Fiesta  Poliéster   Ajustado  Largo   Todas
# 4  Diario, Cena, Trabajo, Fiesta  Poliéster  Oversized  Largo   Todas
#
#              Brand                                              Image  Weight
# 0            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 1  Seven and seven  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 2            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 3            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 4            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 🔄 Q-Table cargada con vectores (State, Action).
# 🔁 Q-Table cargada con 56 combinaciones aprendidas.
# ✅ df contiene datos antes de generar outfits:
#    Image_ID    Type  Color                     Style  \
# 0         1  Bottom  Beige  Formal, Casual, Elegante
# 1         2  Bottom  Black  Formal, Casual, Elegante
# 2         3  Bottom  Black  Formal, Casual, Elegante
# 3         4  Bottom  Black          Formal, Elegante
# 4         5  Bottom  Black  Formal, Casual, Elegante
#
#                         Occasion   Material        Fit Length Weather  \
# 0          Diario, Cena, Trabajo       Lana   Ajustado  Largo    Frío
# 1          Diario, Cena, Trabajo       Lana   Ajustado  Largo   Todas
# 2          Diario, Cena, Trabajo  Poliéster  Oversized  Largo   Todas
# 3           Diario, Cena, Fiesta  Poliéster   Ajustado  Largo   Todas
# 4  Diario, Cena, Trabajo, Fiesta  Poliéster  Oversized  Largo   Todas
#
#              Brand                                              Image  Weight
# 0            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 1  Seven and seven  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 2            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 3            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 4            Todas  C:\Users\POspina\OneDrive - SLB\Desktop\Backup...     0.0
# 📈 Feedback histórico cargado: 102 interacciones (antes de limpieza).
# ✅ Feedback único conservado: 57 entradas tras limpieza.
# 📈 Feedback histórico cargado: 102 interacciones (antes de limpieza).
# ✅ Feedback único conservado: 57 entradas tras limpieza.
# C:\Users\POspina\AppData\Local\Temp\ipykernel_21172\2770905500.py:662: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_available["Brand_norm"] = df_available["Brand"].astype(str).apply(
# C:\Users\POspina\AppData\Local\Temp\ipykernel_21172\2770905500.py:672: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_available.drop(columns=["Brand_norm"], inplace=True)
# 💬 Califica el Outfit 1 [60, 204] (1=Me gusta, 0=No me gusta):  1
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# 💬 Califica el Outfit 2 [52, 201, 18] (1=Me gusta, 0=No me gusta):  1
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# 💬 Califica el Outfit 3 [91, 204] (1=Me gusta, 0=No me gusta):  1
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# 💬 Califica el Outfit 4 [54, 114, 200] (1=Me gusta, 0=No me gusta):  1
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# 💬 Califica el Outfit 5 [100, 202] (1=Me gusta, 0=No me gusta):  1
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# ✅ Q-Table guardada con vectores en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\q_table.xlsx
# 🔄 Tasa de exploración actualizada: ε = 0.9500
# 🛠️ Parámetros de aprendizaje guardados: ε=0.9500
# 💖 Tasa de aceptación para 'By Paola Ospina': 90.32%
# 💖 Tasa de aceptación para 'By Paola Ospina': 90.32%
# 🧪 Nuevo límite de prendas recientes: 11 con tasa de éxito del 86.96%
# ¿Quieres evaluar más outfits? (s/n):  n
# Gracias por evaluar los outfits. ¡Hasta luego!
# 📁 Feedback guardado como CSV en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\Feedback\feedback_2025-08-12_20-45-39.csv
# C:\Users\POspina\AppData\Local\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\POspina\AppData\Local\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📂 Cargando archivo más reciente: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\OUTPUT_CODIGO\feedback_2025-04-22_18-44-42.csv
# C:\Users\POspina\AppData\Local\Temp\ipykernel_21172\2770905500.py:1159: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\POspina\AppData\Local\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Object `gustadas` not found.
# ⚠️ Aún no hay prendas de la marca con likes registrados.
# ❗ Aún no hay prendas de la marca con likes registrados.
#
# --- KPIs del Sistema ---
# 🎯 Precisión del modelo: 86.96%
# 😊 Satisfacción del usuario: 86.96%
# 💖 Tasa de aceptación para 'By Paola Ospina': 90.32%
# 🎯 Precisión del modelo: 86.96%
# 😊 Satisfacción del usuario: 86.96%
# 💖 Tasa de aceptación para 'By Paola Ospina': 90.32%
# 📂 KPIs guardados exitosamente en: C:\Users\POspina\OneDrive - SLB\Desktop\Backup\Tesis\Closet\paola\kpis.xlsx
